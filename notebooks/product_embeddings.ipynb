# %%
# %%bash
#
# cd ../hyperbolics
#
# # Environment management
# # conda create -n hyperbolics python=3.7
# # conda activate hyperbolics
# # conda install pytorch torchvision -c pytorch
# # pip install -r requirements.txt
#
# if [ -d "test" ]; then
#     rm -rf test
# fi
# /home/phil/mambaforge/envs/hyperbolics/bin/python scripts/products.py test
# chmod +x test/cmds0.sh
#
# # Replace 'python' with '/home/phil/mambaforge/envs/hyperbolics/bin/python' in cmds0.sh
# sed -i 's/python/\/home\/phil\/mambaforge\/envs\/hyperbolics\/bin\/python/' test/cmds0.sh
# test/cmds0.sh
# Out:
# 2024-06-27T11:04:55 Distortion avg=0.9593349004129225 wc=2485.9314898662506 me=2.6039117537335117 mc=954.6911435465892 nan_elements=0
# 2024-06-27T11:04:55 MAP = 1.0
# 2024-06-27T11:04:55 scale=[array([1.00002074]), array([1.00002047])]
# 2024-06-27T11:04:55 Saving model into test2/usca312.H5-2.lr0.001.emb.500 623.987046187614
# 2024-06-27T11:04:55 *** End Major Checkpoint
#
# 2024-06-27T11:04:55 501 loss=0.92504020608198
# 2024-06-27T11:04:55 502 loss=0.9249372676017269
# 2024-06-27T11:04:55 Logging to test/polblogs.H10-1.lr0.001.burnin10.log
# ...

# %%
print("Hello world")
# Out:
# Hello world
